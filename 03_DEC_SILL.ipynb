# %%
import pandas as pd
import numpy as np

# %%
mwd = pd.read_csv("mwd_supplementary.csv"); mwd
# Out:
#           Hole id   Depth                 Time  Penetration rate  \
# 0      29be0312e2   0.025  2017-02-10T08:42:16             1.821
# 1      29be0312e2   0.050  2017-02-10T08:42:16             3.126
# 2      29be0312e2   0.077  2017-02-10T08:42:17             2.958
# 3      29be0312e2   0.106  2017-02-10T08:42:17             2.720
# 4      29be0312e2   0.131  2017-02-10T08:42:18             2.602
# ...           ...     ...                  ...               ...
# 10598  c92afa1018  14.384  2017-02-10T14.39.46             2.237
# 10599  c92afa1018  14.405  2017-02-10T14.39.46             2.209
# 10600  c92afa1018  14.427  2017-02-10T14.39.47             2.089
# 10601  c92afa1018  14.450  2017-02-10T14.39.47             2.406
# 10602  c92afa1018  14.476  2017-02-10T14.39.48             2.420
#
#        Percussion pressure  Feed pressure  Flush air pressure  \
# 0                  124.280         23.702               4.621
# 1                  136.658         25.768               5.064
# 2                  140.218         26.415               5.355
# 3                  142.401         26.852               5.630
# 4                  139.546         26.939               5.845
# ...                    ...            ...                 ...
# 10598              189.882         88.945              11.200
# 10599              189.661         88.597              11.184
# 10600              189.753         86.117              11.169
# 10601              189.870         84.576              11.169
# 10602              189.460         84.856              11.184
#
#        Rotation pressure  Dampening pressure  Hardness  Salve  HoleNo
# 0                 38.586              38.914     4.216   1938      13
# 1                 38.364              39.837     8.418   1938      13
# 2                 37.695              40.437     7.732   1938      13
# 3                 37.928              40.752     6.842   1938      13
# 4                 37.751              41.061     6.512   1938      13
# ...                  ...                 ...       ...    ...     ...
# 10598             57.552              68.330     4.235   1941      21
# 10599             59.075              69.237     4.144   1941      21
# 10600             60.732              64.580     3.724   1941      21
# 10601             59.952              63.109     4.827   1941      21
# 10602             60.789              64.625     4.888   1941      21
#
# [10603 rows x 12 columns]

# %%
mwd_new = mwd[mwd.Depth<=3]; mwd_new
# Out:
#           Hole id  Depth                 Time  Penetration rate  \
# 0      29be0312e2  0.025  2017-02-10T08:42:16             1.821
# 1      29be0312e2  0.050  2017-02-10T08:42:16             3.126
# 2      29be0312e2  0.077  2017-02-10T08:42:17             2.958
# 3      29be0312e2  0.106  2017-02-10T08:42:17             2.720
# 4      29be0312e2  0.131  2017-02-10T08:42:18             2.602
# ...           ...    ...                  ...               ...
# 10133  c92afa1018  2.902  2017-02-10T14.33.19             2.103
# 10134  c92afa1018  2.929  2017-02-10T14.33.20             2.058
# 10135  c92afa1018  2.950  2017-02-10T14.33.21             2.187
# 10136  c92afa1018  2.973  2017-02-10T14.33.21             2.221
# 10137  c92afa1018  2.994  2017-02-10T14.33.22             2.205
#
#        Percussion pressure  Feed pressure  Flush air pressure  \
# 0                  124.280         23.702               4.621
# 1                  136.658         25.768               5.064
# 2                  140.218         26.415               5.355
# 3                  142.401         26.852               5.630
# 4                  139.546         26.939               5.845
# ...                    ...            ...                 ...
# 10133              191.261         89.161               7.788
# 10134              191.499         89.401               7.803
# 10135              191.398         88.446               7.818
# 10136              191.362         89.049               7.818
# 10137              191.507         89.224               7.818
#
#        Rotation pressure  Dampening pressure  Hardness  Salve  HoleNo
# 0                 38.586              38.914     4.216   1938      13
# 1                 38.364              39.837     8.418   1938      13
# 2                 37.695              40.437     7.732   1938      13
# 3                 37.928              40.752     6.842   1938      13
# 4                 37.751              41.061     6.512   1938      13
# ...                  ...                 ...       ...    ...     ...
# 10133             53.658              73.285     3.395   1941      21
# 10134             53.051              74.118     3.232   1941      21
# 10135             53.788              72.150     3.685   1941      21
# 10136             53.613              73.462     3.805   1941      21
# 10137             52.633              74.787     3.746   1941      21
#
# [1949 rows x 12 columns]

# %%
groups = mwd_new.groupby(mwd_new['Hole id'])
h_db95d6684b = groups.get_group('db95d6684b'); h_db95d6684b['class'] = np.where((h_db95d6684b['HoleNo']==23) & (h_db95d6684b['Salve']==1938) & (h_db95d6684b['Depth']<=0.75), 0, 1); 
h_07b4bd5a9d = groups.get_group('07b4bd5a9d'); h_07b4bd5a9d['class'] = np.where((h_07b4bd5a9d['HoleNo']==2) & (h_07b4bd5a9d['Salve']==1938) & (h_07b4bd5a9d['Depth']<=1.65), 0, 1);
h_14c2f806ff = groups.get_group('14c2f806ff'); h_14c2f806ff['class'] = np.where((h_14c2f806ff['HoleNo']==28) & (h_14c2f806ff['Salve']==1941) & (h_14c2f806ff['Depth']<0.40), 0, 1);
h_29be0312e2 = groups.get_group('29be0312e2'); h_29be0312e2['class'] = np.where((h_29be0312e2['HoleNo']==13) & (h_29be0312e2['Salve']==1938) & (h_29be0312e2['Depth']<=1.2), 0, 1); 
h_35f0f14168 = groups.get_group('35f0f14168'); h_35f0f14168['class'] = np.where((h_35f0f14168['HoleNo']==24) & (h_35f0f14168['Salve']==1939) & (0.35<h_35f0f14168['Depth']) & (h_35f0f14168['Depth']<1.7), 0, 1);
h_432e88547b = groups.get_group('432e88547b'); h_432e88547b['class'] = np.where((h_432e88547b['HoleNo']==21) & (h_432e88547b['Salve']==1939) & (h_432e88547b['Depth']<0.75), 0, 1);
h_519ca0a683 = groups.get_group('519ca0a683'); h_519ca0a683['class'] = np.where((h_519ca0a683['HoleNo']==85) & (h_519ca0a683['Salve']==1940) & (h_519ca0a683['Depth']<=1.75), 0, 1);
h_53034ece37 = groups.get_group('53034ece37'); h_53034ece37['class'] = np.where((h_53034ece37['HoleNo']==34) & (h_53034ece37['Salve']==1938) & (h_53034ece37['Depth']<0.55), 0, 1);
h_5b88eb1e23 = groups.get_group('5b88eb1e23'); h_5b88eb1e23['class'] = np.where((h_5b88eb1e23['HoleNo']==27) & (h_5b88eb1e23['Salve']==1939) & (h_5b88eb1e23['Depth']<=1.45), 0, 1);
h_6a7cb0d5af = groups.get_group('6a7cb0d5af'); h_6a7cb0d5af['class'] = np.where((h_6a7cb0d5af['HoleNo']==76) & (h_6a7cb0d5af['Salve']==1940) & (h_6a7cb0d5af['Depth']<=0.75), 0, 1);
h_b8960bac07 = groups.get_group('b8960bac07'); h_b8960bac07['class'] = np.where((h_b8960bac07['HoleNo']==79) & (h_b8960bac07['Salve']==1940) & (0.30<h_b8960bac07['Depth']) & (h_b8960bac07['Depth']<1.25), 0, 1);
h_be8b244c5c = groups.get_group('be8b244c5c'); h_be8b244c5c['class'] = np.where((h_be8b244c5c['HoleNo']==7) & (h_be8b244c5c['Salve']==1941) & (h_be8b244c5c['Depth']<=1.25), 0, 1);
h_c4e502a4b2 = groups.get_group('c4e502a4b2'); h_c4e502a4b2['class'] = np.where((h_c4e502a4b2['HoleNo']==14) & (h_c4e502a4b2['Salve']==1941) & (h_c4e502a4b2['Depth']<0.40), 0, 1);
h_c69005e9d6 = groups.get_group('c69005e9d6'); h_c69005e9d6['class'] = np.where((h_c69005e9d6['HoleNo']==18) & (h_c69005e9d6['Salve']==1939) & (h_c69005e9d6['Depth']<0.4), 0, 1);
h_c92afa1018 = groups.get_group('c92afa1018'); h_c92afa1018['class'] = np.where((h_c92afa1018['HoleNo']==21) & (h_c92afa1018['Salve']==1941) & (0.30<h_c92afa1018['Depth']) & (h_c92afa1018['Depth']<2.35), 0, 1);
h_d6abc83da1 = groups.get_group('d6abc83da1'); h_d6abc83da1['class'] = np.where((h_d6abc83da1['HoleNo']==35) & (h_d6abc83da1['Salve']==1941) & (h_d6abc83da1['Depth']<=0.80), 0, 1);
# Out:
# <ipython-input-122-4acd69b184e5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_db95d6684b = groups.get_group('db95d6684b'); h_db95d6684b['class'] = np.where((h_db95d6684b['HoleNo']==23) & (h_db95d6684b['Salve']==1938) & (h_db95d6684b['Depth']<=0.75), 0, 1);
# <ipython-input-122-4acd69b184e5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_07b4bd5a9d = groups.get_group('07b4bd5a9d'); h_07b4bd5a9d['class'] = np.where((h_07b4bd5a9d['HoleNo']==2) & (h_07b4bd5a9d['Salve']==1938) & (h_07b4bd5a9d['Depth']<=1.65), 0, 1);
# <ipython-input-122-4acd69b184e5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_14c2f806ff = groups.get_group('14c2f806ff'); h_14c2f806ff['class'] = np.where((h_14c2f806ff['HoleNo']==28) & (h_14c2f806ff['Salve']==1941) & (h_14c2f806ff['Depth']<0.40), 0, 1);
# <ipython-input-122-4acd69b184e5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_29be0312e2 = groups.get_group('29be0312e2'); h_29be0312e2['class'] = np.where((h_29be0312e2['HoleNo']==13) & (h_29be0312e2['Salve']==1938) & (h_29be0312e2['Depth']<=1.2), 0, 1);
# <ipython-input-122-4acd69b184e5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_35f0f14168 = groups.get_group('35f0f14168'); h_35f0f14168['class'] = np.where((h_35f0f14168['HoleNo']==24) & (h_35f0f14168['Salve']==1939) & (0.35<h_35f0f14168['Depth']) & (h_35f0f14168['Depth']<1.7), 0, 1);
# <ipython-input-122-4acd69b184e5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_432e88547b = groups.get_group('432e88547b'); h_432e88547b['class'] = np.where((h_432e88547b['HoleNo']==21) & (h_432e88547b['Salve']==1939) & (h_432e88547b['Depth']<0.75), 0, 1);
# <ipython-input-122-4acd69b184e5>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_519ca0a683 = groups.get_group('519ca0a683'); h_519ca0a683['class'] = np.where((h_519ca0a683['HoleNo']==85) & (h_519ca0a683['Salve']==1940) & (h_519ca0a683['Depth']<=1.75), 0, 1);
# <ipython-input-122-4acd69b184e5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_53034ece37 = groups.get_group('53034ece37'); h_53034ece37['class'] = np.where((h_53034ece37['HoleNo']==34) & (h_53034ece37['Salve']==1938) & (h_53034ece37['Depth']<0.55), 0, 1);
# <ipython-input-122-4acd69b184e5>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_5b88eb1e23 = groups.get_group('5b88eb1e23'); h_5b88eb1e23['class'] = np.where((h_5b88eb1e23['HoleNo']==27) & (h_5b88eb1e23['Salve']==1939) & (h_5b88eb1e23['Depth']<=1.45), 0, 1);
# <ipython-input-122-4acd69b184e5>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_6a7cb0d5af = groups.get_group('6a7cb0d5af'); h_6a7cb0d5af['class'] = np.where((h_6a7cb0d5af['HoleNo']==76) & (h_6a7cb0d5af['Salve']==1940) & (h_6a7cb0d5af['Depth']<=0.75), 0, 1);
# <ipython-input-122-4acd69b184e5>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_b8960bac07 = groups.get_group('b8960bac07'); h_b8960bac07['class'] = np.where((h_b8960bac07['HoleNo']==79) & (h_b8960bac07['Salve']==1940) & (0.30<h_b8960bac07['Depth']) & (h_b8960bac07['Depth']<1.25), 0, 1);
# <ipython-input-122-4acd69b184e5>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_be8b244c5c = groups.get_group('be8b244c5c'); h_be8b244c5c['class'] = np.where((h_be8b244c5c['HoleNo']==7) & (h_be8b244c5c['Salve']==1941) & (h_be8b244c5c['Depth']<=1.25), 0, 1);
# <ipython-input-122-4acd69b184e5>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_c4e502a4b2 = groups.get_group('c4e502a4b2'); h_c4e502a4b2['class'] = np.where((h_c4e502a4b2['HoleNo']==14) & (h_c4e502a4b2['Salve']==1941) & (h_c4e502a4b2['Depth']<0.40), 0, 1);
# <ipython-input-122-4acd69b184e5>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_c69005e9d6 = groups.get_group('c69005e9d6'); h_c69005e9d6['class'] = np.where((h_c69005e9d6['HoleNo']==18) & (h_c69005e9d6['Salve']==1939) & (h_c69005e9d6['Depth']<0.4), 0, 1);
# <ipython-input-122-4acd69b184e5>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_c92afa1018 = groups.get_group('c92afa1018'); h_c92afa1018['class'] = np.where((h_c92afa1018['HoleNo']==21) & (h_c92afa1018['Salve']==1941) & (0.30<h_c92afa1018['Depth']) & (h_c92afa1018['Depth']<2.35), 0, 1);
# <ipython-input-122-4acd69b184e5>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h_d6abc83da1 = groups.get_group('d6abc83da1'); h_d6abc83da1['class'] = np.where((h_d6abc83da1['HoleNo']==35) & (h_d6abc83da1['Salve']==1941) & (h_d6abc83da1['Depth']<=0.80), 0, 1);

# %%
classified_data = pd.concat([h_07b4bd5a9d, h_14c2f806ff, h_29be0312e2,h_35f0f14168,h_432e88547b,h_519ca0a683,h_53034ece37,h_5b88eb1e23,h_6a7cb0d5af,h_b8960bac07,h_be8b244c5c,
                             h_c4e502a4b2,h_c69005e9d6,h_c92afa1018,h_d6abc83da1,h_db95d6684b]); 

classified_data.drop(['Time','Salve','HoleNo','Hardness'], axis=1, inplace=True); 
classified_data.reset_index(drop=True, inplace=True)

# %%
hole_ids = classified_data['Hole id'].unique(); hole_ids
# Out:
# array(['07b4bd5a9d', '14c2f806ff', '29be0312e2', '35f0f14168',
#        '432e88547b', '519ca0a683', '53034ece37', '5b88eb1e23',
#        '6a7cb0d5af', 'b8960bac07', 'be8b244c5c', 'c4e502a4b2',
#        'c69005e9d6', 'c92afa1018', 'd6abc83da1', 'db95d6684b'],
#       dtype=object)

# %% [raw]
# fark = []
# for i in range(len(depth)-1):
#     if (depth.iloc[i] < 0.025).bool():
#         fark.append(depth.iloc[i])
#     else:
#         fark.append(np.absolute(depth.iloc[i+1]-depth.iloc[i]))
# print(pd.DataFrame(fark))

# %%
derinlik_farki = []
for i in range(len(classified_data)):
    if (classified_data['Depth'].iloc[i] < 0.025):
        derinlik_farki.append(classified_data['Depth'].iloc[i])
    else:
        derinlik_farki.append(np.around(np.absolute(classified_data['Depth'].iloc[i]-classified_data['Depth'].iloc[i-1]), decimals=4))
print(pd.DataFrame(derinlik_farki))
# Out:
#           0
# 0     0.021
# 1     0.025
# 2     0.027
# 3     0.022
# 4     0.021
# ...     ...
# 1869  0.023
# 1870  0.022
# 1871  0.022
# 1872  0.029
# 1873  0.028
#
# [1874 rows x 1 columns]

# %%
classified_data['der_farki'] = derinlik_farki; classified_data
# Out:
#          Hole id  Depth  Penetration rate  Percussion pressure  Feed pressure  \
# 0     07b4bd5a9d  0.021             0.684              140.632         24.497
# 1     07b4bd5a9d  0.046             1.618              138.312         27.815
# 2     07b4bd5a9d  0.073             2.564              139.276         31.805
# 3     07b4bd5a9d  0.095             1.075              138.612         29.890
# 4     07b4bd5a9d  0.116             0.804              138.026         32.925
# ...          ...    ...               ...                  ...            ...
# 1869  db95d6684b  2.877             2.141              190.978         89.034
# 1870  db95d6684b  2.899             2.369              190.875         89.038
# 1871  db95d6684b  2.921             2.105              190.912         88.901
# 1872  db95d6684b  2.950             2.134              190.601         88.946
# 1873  db95d6684b  2.978             2.077              190.587         89.182
#
#       Flush air pressure  Rotation pressure  Dampening pressure  class  \
# 0                  2.173             48.983              43.046      0
# 1                  2.203             45.897              43.541      0
# 2                  2.203             49.007              43.871      0
# 3                  2.188             49.103              43.911      0
# 4                  2.218             45.629              43.147      0
# ...                  ...                ...                 ...    ...
# 1869               7.176             48.738              70.441      1
# 1870               7.176             48.278              70.963      1
# 1871               7.176             46.823              71.992      1
# 1872               7.191             46.610              71.051      1
# 1873               7.191             46.690              71.071      1
#
#       der_farki
# 0         0.021
# 1         0.025
# 2         0.027
# 3         0.022
# 4         0.021
# ...         ...
# 1869      0.023
# 1870      0.022
# 1871      0.022
# 1872      0.029
# 1873      0.028
#
# [1874 rows x 10 columns]

# %%
train_data = classified_data[(classified_data['Hole id'] != 'db95d6684b') & (classified_data['Hole id'] != '29be0312e2') & (classified_data['Hole id'] != 'd6abc83da1')
                             &(classified_data['Hole id'] != 'c92afa1018')]; train_data
# Out:
#          Hole id  Depth  Penetration rate  Percussion pressure  Feed pressure  \
# 0     07b4bd5a9d  0.021             0.684              140.632         24.497
# 1     07b4bd5a9d  0.046             1.618              138.312         27.815
# 2     07b4bd5a9d  0.073             2.564              139.276         31.805
# 3     07b4bd5a9d  0.095             1.075              138.612         29.890
# 4     07b4bd5a9d  0.116             0.804              138.026         32.925
# ...          ...    ...               ...                  ...            ...
# 1520  c69005e9d6  2.890             2.370              190.909         88.543
# 1521  c69005e9d6  2.916             2.467              191.407         88.648
# 1522  c69005e9d6  2.940             2.506              191.205         88.232
# 1523  c69005e9d6  2.964             2.324              190.282         88.584
# 1524  c69005e9d6  2.985             2.169              188.618         89.154
#
#       Flush air pressure  Rotation pressure  Dampening pressure  class  \
# 0                  2.173             48.983              43.046      0
# 1                  2.203             45.897              43.541      0
# 2                  2.203             49.007              43.871      0
# 3                  2.188             49.103              43.911      0
# 4                  2.218             45.629              43.147      0
# ...                  ...                ...                 ...    ...
# 1520               6.962             53.734              71.049      1
# 1521               6.946             53.550              72.848      1
# 1522               6.962             53.577              71.447      1
# 1523               6.992             54.820              73.276      1
# 1524               6.977             55.206              73.303      1
#
#       der_farki
# 0         0.021
# 1         0.025
# 2         0.027
# 3         0.022
# 4         0.021
# ...         ...
# 1520      0.025
# 1521      0.026
# 1522      0.024
# 1523      0.024
# 1524      0.021
#
# [1408 rows x 10 columns]

# %%
test_data = classified_data[(classified_data['Hole id'] == 'db95d6684b') | (classified_data['Hole id'] == '29be0312e2') |(classified_data['Hole id'] == 'd6abc83da1')
                             |(classified_data['Hole id'] == 'c92afa1018')]; test_data
# Out:
#          Hole id  Depth  Penetration rate  Percussion pressure  Feed pressure  \
# 231   29be0312e2  0.025             1.821              124.280         23.702
# 232   29be0312e2  0.050             3.126              136.658         25.768
# 233   29be0312e2  0.077             2.958              140.218         26.415
# 234   29be0312e2  0.106             2.720              142.401         26.852
# 235   29be0312e2  0.131             2.602              139.546         26.939
# ...          ...    ...               ...                  ...            ...
# 1869  db95d6684b  2.877             2.141              190.978         89.034
# 1870  db95d6684b  2.899             2.369              190.875         89.038
# 1871  db95d6684b  2.921             2.105              190.912         88.901
# 1872  db95d6684b  2.950             2.134              190.601         88.946
# 1873  db95d6684b  2.978             2.077              190.587         89.182
#
#       Flush air pressure  Rotation pressure  Dampening pressure  class  \
# 231                4.621             38.586              38.914      0
# 232                5.064             38.364              39.837      0
# 233                5.355             37.695              40.437      0
# 234                5.630             37.928              40.752      0
# 235                5.845             37.751              41.061      0
# ...                  ...                ...                 ...    ...
# 1869               7.176             48.738              70.441      1
# 1870               7.176             48.278              70.963      1
# 1871               7.176             46.823              71.992      1
# 1872               7.191             46.610              71.051      1
# 1873               7.191             46.690              71.071      1
#
#       der_farki
# 231       2.972
# 232       0.025
# 233       0.027
# 234       0.029
# 235       0.025
# ...         ...
# 1869      0.023
# 1870      0.022
# 1871      0.022
# 1872      0.029
# 1873      0.028
#
# [466 rows x 10 columns]

# %%
X_train = train_data.drop(['Depth',"Dampening pressure", "Percussion pressure","Hole id","class",'der_farki'], axis=1)
y_train = train_data[["Hole id",'class','der_farki']]

X_test = test_data.drop(['Depth',"Dampening pressure", "Percussion pressure","Hole id", "class", 'der_farki'], axis=1)
y_test = test_data[["Hole id",'class','der_farki']]

X_train
# Out:
#       Penetration rate  Feed pressure  Flush air pressure  Rotation pressure
# 0                0.684         24.497               2.173             48.983
# 1                1.618         27.815               2.203             45.897
# 2                2.564         31.805               2.203             49.007
# 3                1.075         29.890               2.188             49.103
# 4                0.804         32.925               2.218             45.629
# ...                ...            ...                 ...                ...
# 1520             2.370         88.543               6.962             53.734
# 1521             2.467         88.648               6.946             53.550
# 1522             2.506         88.232               6.962             53.577
# 1523             2.324         88.584               6.992             54.820
# 1524             2.169         89.154               6.977             55.206
#
# [1408 rows x 4 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report

model = RandomForestClassifier(max_depth=5)
n_estimators = range(100, 120)
max_features = ['sqrt', 'log2']

grid = dict(n_estimators=n_estimators,max_features=max_features)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1) 

#Repeats Stratified K-Fold n times with different randomization in each repetition.
#This cross-validation object is a variation of KFold that returns stratified folds. The folds are made by preserving the percentage of samples for each class.
#n_splits, Number of folds. Must be at least 2.
#n_repeats, Number of times cross-validator needs to be repeated.

grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='recall')
grid_result = grid_search.fit(X_train, y_train['class'])

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.945936 using {'max_features': 'log2', 'n_estimators': 109}
# 0.943936 (0.021871) with: {'max_features': 'sqrt', 'n_estimators': 100}
# 0.944266 (0.021896) with: {'max_features': 'sqrt', 'n_estimators': 101}
# 0.942933 (0.021351) with: {'max_features': 'sqrt', 'n_estimators': 102}
# 0.942263 (0.021130) with: {'max_features': 'sqrt', 'n_estimators': 103}
# 0.943266 (0.021690) with: {'max_features': 'sqrt', 'n_estimators': 104}
# 0.943596 (0.022030) with: {'max_features': 'sqrt', 'n_estimators': 105}
# 0.942929 (0.020405) with: {'max_features': 'sqrt', 'n_estimators': 106}
# 0.940933 (0.021839) with: {'max_features': 'sqrt', 'n_estimators': 107}
# 0.945266 (0.023236) with: {'max_features': 'sqrt', 'n_estimators': 108}
# 0.945269 (0.020803) with: {'max_features': 'sqrt', 'n_estimators': 109}
# 0.943596 (0.022181) with: {'max_features': 'sqrt', 'n_estimators': 110}
# 0.942929 (0.023303) with: {'max_features': 'sqrt', 'n_estimators': 111}
# 0.942603 (0.020986) with: {'max_features': 'sqrt', 'n_estimators': 112}
# 0.944259 (0.019171) with: {'max_features': 'sqrt', 'n_estimators': 113}
# 0.944929 (0.018814) with: {'max_features': 'sqrt', 'n_estimators': 114}
# 0.943939 (0.020928) with: {'max_features': 'sqrt', 'n_estimators': 115}
# 0.942599 (0.021777) with: {'max_features': 'sqrt', 'n_estimators': 116}
# 0.943933 (0.021730) with: {'max_features': 'sqrt', 'n_estimators': 117}
# 0.944269 (0.020468) with: {'max_features': 'sqrt', 'n_estimators': 118}
# 0.942266 (0.022642) with: {'max_features': 'sqrt', 'n_estimators': 119}
# 0.944266 (0.022497) with: {'max_features': 'log2', 'n_estimators': 100}
# 0.945269 (0.023652) with: {'max_features': 'log2', 'n_estimators': 101}
# 0.943933 (0.021421) with: {'max_features': 'log2', 'n_estimators': 102}
# 0.943263 (0.020759) with: {'max_features': 'log2', 'n_estimators': 103}
# 0.944266 (0.020966) with: {'max_features': 'log2', 'n_estimators': 104}
# 0.944269 (0.020951) with: {'max_features': 'log2', 'n_estimators': 105}
# 0.942599 (0.020026) with: {'max_features': 'log2', 'n_estimators': 106}
# 0.942606 (0.022209) with: {'max_features': 'log2', 'n_estimators': 107}
# 0.945603 (0.020635) with: {'max_features': 'log2', 'n_estimators': 108}
# 0.945936 (0.019965) with: {'max_features': 'log2', 'n_estimators': 109}
# 0.943933 (0.021886) with: {'max_features': 'log2', 'n_estimators': 110}
# 0.945599 (0.021283) with: {'max_features': 'log2', 'n_estimators': 111}
# 0.944603 (0.022045) with: {'max_features': 'log2', 'n_estimators': 112}
# 0.941929 (0.023619) with: {'max_features': 'log2', 'n_estimators': 113}
# 0.944599 (0.022057) with: {'max_features': 'log2', 'n_estimators': 114}
# 0.942266 (0.021429) with: {'max_features': 'log2', 'n_estimators': 115}
# 0.942599 (0.019855) with: {'max_features': 'log2', 'n_estimators': 116}
# 0.942596 (0.021483) with: {'max_features': 'log2', 'n_estimators': 117}
# 0.943263 (0.019260) with: {'max_features': 'log2', 'n_estimators': 118}
# 0.943263 (0.021855) with: {'max_features': 'log2', 'n_estimators': 119}

# %%
model_rf = grid_search.best_estimator_
pred = model_rf.predict(X_test)
pred = pd.DataFrame(pred).set_index(y_test.index)
train_pred = model_rf.predict(X_train)
train_pred = pd.DataFrame(train_pred).set_index(y_train.index)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cm_test = confusion_matrix(pred, y_test['class'])
sns.heatmap(cm_test, annot=True, fmt='.1f')
plt.title('CONF MATR')
plt.xlabel('Predictions')
plt.ylabel('True Values');

# %%
cm_train = confusion_matrix(train_pred, y_train['class'])
sns.heatmap(cm_train, annot=True, fmt='.1f')
plt.title('CONF MATR')
plt.xlabel('Predictions')
plt.ylabel('True Values');

# %%
all_preds = pd.concat([ pd.DataFrame(train_pred),pd.DataFrame(pred)], axis=0)
all_preds
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1944  1
# 1945  1
# 1946  1
# 1947  1
# 1948  1
#
# [1949 rows x 1 columns]

# %%
all_true = pd.concat([y_train, y_test], axis=0); all_true
# Out:
#          Hole id  class  der_farki
# 0     07b4bd5a9d      0      0.021
# 1     07b4bd5a9d      0      0.025
# 2     07b4bd5a9d      0      0.027
# 3     07b4bd5a9d      0      0.022
# 4     07b4bd5a9d      0      0.021
# ...          ...    ...        ...
# 1944  db95d6684b      1      0.023
# 1945  db95d6684b      1      0.022
# 1946  db95d6684b      1      0.022
# 1947  db95d6684b      1      0.029
# 1948  db95d6684b      1      0.028
#
# [1949 rows x 3 columns]

# %%
all_ = all_preds.join(all_true); all_
# Out:
#       0     Hole id  class  der_farki
# 0     0  07b4bd5a9d      0      0.021
# 1     0  07b4bd5a9d      0      0.025
# 2     0  07b4bd5a9d      0      0.027
# 3     0  07b4bd5a9d      0      0.022
# 4     0  07b4bd5a9d      0      0.021
# ...  ..         ...    ...        ...
# 1944  1  db95d6684b      1      0.023
# 1945  1  db95d6684b      1      0.022
# 1946  1  db95d6684b      1      0.022
# 1947  1  db95d6684b      1      0.029
# 1948  1  db95d6684b      1      0.028
#
# [1949 rows x 4 columns]

# %%
import joblib
filename = 'RF_sill_model.sav'
joblib.dump(model_rf, filename)
# Out:
# ['RF_sill_model.sav']

# %%
#all_.to_excel('all_.xlsx')

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [1, 0.1, 0.01, 0.001,0.0001]

cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

#KFold(n_splits=4)
grid = dict(solver= solvers, penalty=penalty, C=c_values)
grid_search = GridSearchCV(estimator=model, param_grid=grid, cv=cv, n_jobs=-1, scoring='recall')
grid_result = grid_search.fit(X_train, y_train['class'])

print('Best hyperparameters:', grid_result.best_params_)
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best hyperparameters: {'C': 0.0001, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.942606 (0.021764) with: {'C': 1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.942606 (0.021764) with: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.940943 (0.024139) with: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.939273 (0.024629) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.939273 (0.024629) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.941276 (0.023058) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.935936 (0.023186) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.935936 (0.023186) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.941616 (0.023253) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.936609 (0.024132) with: {'C': 0.001, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.936609 (0.024132) with: {'C': 0.001, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.944616 (0.021416) with: {'C': 0.001, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.937609 (0.024593) with: {'C': 0.0001, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.937609 (0.024593) with: {'C': 0.0001, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.949623 (0.021217) with: {'C': 0.0001, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
model_log = grid_search.best_estimator_
pred = model_log.predict(X_test)
pred = pd.DataFrame(pred).set_index(y_test.index)
train_pred = model_log.predict(X_train)
train_pred = pd.DataFrame(train_pred).set_index(y_train.index)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cm_test = confusion_matrix(pred, y_test['class'])
sns.heatmap(cm_test, annot=True, fmt='.1f')
plt.title('CONF MATR')
plt.xlabel('Predictions')
plt.ylabel('True Values');

# %%
cm_train = confusion_matrix(train_pred, y_train['class'])
sns.heatmap(cm_train, annot=True, fmt='.1f')
plt.title('CONF MATR')
plt.xlabel('Predictions')
plt.ylabel('True Values');

# %%
all_preds = pd.concat([ pd.DataFrame(train_pred),pd.DataFrame(pred)], axis=0)
all_preds
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1944  1
# 1945  1
# 1946  1
# 1947  1
# 1948  1
#
# [1949 rows x 1 columns]

# %%
all_true = pd.concat([y_train, y_test], axis=0); all_true
# Out:
#          Hole id  class  der_farki
# 0     07b4bd5a9d      0      0.021
# 1     07b4bd5a9d      0      0.025
# 2     07b4bd5a9d      0      0.027
# 3     07b4bd5a9d      0      0.022
# 4     07b4bd5a9d      0      0.021
# ...          ...    ...        ...
# 1944  db95d6684b      1      0.023
# 1945  db95d6684b      1      0.022
# 1946  db95d6684b      1      0.022
# 1947  db95d6684b      1      0.029
# 1948  db95d6684b      1      0.028
#
# [1949 rows x 3 columns]

# %%
all_ = all_preds.join(all_true); all_
# Out:
#       0     Hole id  class  der_farki
# 0     0  07b4bd5a9d      0      0.021
# 1     0  07b4bd5a9d      0      0.025
# 2     0  07b4bd5a9d      0      0.027
# 3     0  07b4bd5a9d      0      0.022
# 4     0  07b4bd5a9d      0      0.021
# ...  ..         ...    ...        ...
# 1944  1  db95d6684b      1      0.023
# 1945  1  db95d6684b      1      0.022
# 1946  1  db95d6684b      1      0.022
# 1947  1  db95d6684b      1      0.029
# 1948  1  db95d6684b      1      0.028
#
# [1949 rows x 4 columns]

# %%
import joblib
filename = 'LOG_sill_model.sav'
joblib.dump(model_log, filename)
# Out:
# ['LOG_sill_model.sav']

# %%
#all_.to_excel('all_Log.xlsx')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
scaler = StandardScaler().fit(X_train)
train_inputs = scaler.transform(X_train)
test_inputs = scaler.transform(X_train)

# %%
from sklearn.svm import SVC

model = SVC(probability=True)
kernel = ['poly','rbf','sigmoid']
C = [10, 100, 200]


grid = dict(kernel=kernel, C=C)
cv=RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

#Repeats Stratified K-Fold n times with different randomization in each repetition.
#This cross-validation object is a variation of KFold that returns stratified folds. The folds are made by preserving the percentage of samples for each class.
#n_splits, Number of folds. Must be at least 2.
#n_repeats, Number of times cross-validator needs to be repeated.

grid_search = GridSearchCV(model, param_grid=grid, cv=cv, n_jobs=-1)
grid_result = grid_search.fit(X_train, y_train['class'])

print('Best %f using %s' % (grid_result.best_score_, grid_result.best_params_))
means =grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, stdev, param in zip(means,stds,params):
    print('%f (%f) with: %r' % (mean, stdev,param))
# Out:
# Best 0.912165 using {'C': 200, 'kernel': 'poly'}
# 0.910029 (0.018221) with: {'C': 10, 'kernel': 'poly'}
# 0.906241 (0.018866) with: {'C': 10, 'kernel': 'rbf'}
# 0.438661 (0.031768) with: {'C': 10, 'kernel': 'sigmoid'}
# 0.911689 (0.016995) with: {'C': 100, 'kernel': 'poly'}
# 0.906949 (0.017582) with: {'C': 100, 'kernel': 'rbf'}
# 0.430616 (0.033867) with: {'C': 100, 'kernel': 'sigmoid'}
# 0.912165 (0.016759) with: {'C': 200, 'kernel': 'poly'}
# 0.907421 (0.018161) with: {'C': 200, 'kernel': 'rbf'}
# 0.430380 (0.034025) with: {'C': 200, 'kernel': 'sigmoid'}

# %%
model_svm = grid_search.best_estimator_
pred = model_svm.predict(X_test)
pred = pd.DataFrame(pred).set_index(y_test.index)
train_pred = model_svm.predict(X_train)
train_pred = pd.DataFrame(train_pred).set_index(y_train.index)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cm_test = confusion_matrix(pred, y_test['class'])
sns.heatmap(cm_test, annot=True, fmt='.1f')
plt.title('CONF MATR')
plt.xlabel('Predictions')
plt.ylabel('True Values');
model_svm.score(X_test, y_test['class'])
# Out:
# 0.8497854077253219

# %%
cm_train = confusion_matrix(train_pred, y_train['class'])
sns.heatmap(cm_train, annot=True, fmt='.1f')
plt.title('CONF MATR')
plt.xlabel('Predictions')
plt.ylabel('True Values');

# %%
all_preds = pd.concat([ pd.DataFrame(train_pred),pd.DataFrame(pred)], axis=0)
all_preds
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1944  1
# 1945  1
# 1946  1
# 1947  1
# 1948  1
#
# [1949 rows x 1 columns]

# %%
all_true = pd.concat([y_train, y_test], axis=0); all_true
# Out:
#          Hole id  class  der_farki
# 0     07b4bd5a9d      0      0.021
# 1     07b4bd5a9d      0      0.025
# 2     07b4bd5a9d      0      0.027
# 3     07b4bd5a9d      0      0.022
# 4     07b4bd5a9d      0      0.021
# ...          ...    ...        ...
# 1944  db95d6684b      1      0.023
# 1945  db95d6684b      1      0.022
# 1946  db95d6684b      1      0.022
# 1947  db95d6684b      1      0.029
# 1948  db95d6684b      1      0.028
#
# [1949 rows x 3 columns]

# %%
all_ = all_preds.join(all_true); all_
# Out:
#       0     Hole id  class  der_farki
# 0     0  07b4bd5a9d      0      0.021
# 1     0  07b4bd5a9d      0      0.025
# 2     0  07b4bd5a9d      0      0.027
# 3     0  07b4bd5a9d      0      0.022
# 4     0  07b4bd5a9d      0      0.021
# ...  ..         ...    ...        ...
# 1944  1  db95d6684b      1      0.023
# 1945  1  db95d6684b      1      0.022
# 1946  1  db95d6684b      1      0.022
# 1947  1  db95d6684b      1      0.029
# 1948  1  db95d6684b      1      0.028
#
# [1949 rows x 4 columns]

# %%
all_.to_excel('svm.xlsx')

# %%
filename = 'svm_sill_model.sav'
joblib.dump(model_svm, filename)

# load the model from disk
loaded_model = joblib.load(filename)
result = loaded_model.score(X_test, y_test['class'])
print(result)
# Out:
# 0.8530612244897959
